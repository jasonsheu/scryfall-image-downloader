# %%
import requests
import time
import os

# %%
#make directories for set if it doesnt exist 
os.makedirs('images/tla', exist_ok=True)
for rarity in ['common', 'uncommon', 'rare', 'mythic']:
    #make directories for rarity if it doesnt exist
    os.makedirs(f'images/tla/{rarity}', exist_ok=True)
    #get all cards in the draft set, change the query for other sets
    r = requests.get(f"https://api.scryfall.com/cards/search?q=e:tla+cn>=1+cn<=286+r:{rarity}").json()
    #respect api rules
    time.sleep(0.1)
    print('got', r.get('total_cards'), 'cards of rarity', rarity)
    cards = r.get('data')
    #iterate through all cards for current rarity
    for card in cards:
        cardname = card.get('name')
        
        #handle mdfc cards and // in names
        if '/' in cardname:
            cardname = cardname.replace('/', '_')       
        color_mapping = {
                'W' : '1',
                'U' : '2',
                'B' : '3',
                'R' : '4',
                'G' : '5'
        }
        #special handling of MDFC cards to get both faces 
        if card.get('card_faces') is not None:
            # for color mapping of mdfc cards, use color of first face to keep the cards together in the file explorer
            first = card.get('card_faces')[0]
            color = first.get('color')
            if color is None or len(color) == 0:
                color_code = '0'
            elif len(color) > 1:
                color_code = '6'
            else:
                color_code = color_mapping.get(color[0])
            for idx, cardface in enumerate(card.get('card_faces')):
                image_url = cardface.get('image_uris').get('normal')
                save_path = f'images/tla/{rarity}/{color_code}_{cardname}_{idx}.jpg'
                response = requests.get(image_url)
                time.sleep(0.2)
                if response.status_code == 200:    
                    with open (save_path, 'wb') as file:
                        file.write(response.content)
                    print(f'downloaded image for {cardname}')
                else:
                    print(f"Failed to download image for {cardname}")
        #regular card case 
        else:
            #create color identity mapping to group images by color in file explorer, remove if not interested in sorty by color and only by name
            color = card.get('color_identity')
            if color is None or len(color) == 0:
                color_code = '0'
            elif len(color) > 1:
                color_code = '6'
            else:
                color_code = color_mapping.get(color[0])
            if cardname == 'Abandon Attachments':
                print(card.get('color_identity'))
                print(color_code)
            
            #get image url and download image
            image_url = card.get('image_uris').get('normal')
            save_path = f'images/tla/{rarity}/{color_code}_{cardname}.jpg'
            response = requests.get(image_url)
            time.sleep(0.2)
            if response.status_code == 200:    
                with open (save_path, 'wb') as file:
                    file.write(response.content)
                print(f'downloaded image for {cardname}')
            else:
                print(f"Failed to download image for {cardname}")
# Out:
# got 96 cards of rarity common
# downloaded image for Aang's Journey
# ['R', 'U']
# 6
# downloaded image for Abandon Attachments
# downloaded image for Airbending Lesson
# downloaded image for Airship Engine Room
# downloaded image for Avatar Enthusiasts
# downloaded image for Azula Always Lies
# downloaded image for Badgermole
# downloaded image for Barrels of Blasting Jelly
# downloaded image for Beetle-Headed Merchants
# downloaded image for Bender's Waterskin
# downloaded image for Boar-q-pine
# downloaded image for Boiling Rock Prison
# downloaded image for Bumi Bash
# downloaded image for Callous Inspector
# downloaded image for Canyon Crawler
# downloaded image for Cat-Owl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 66
#      64 save_path = f'images/tla/{rarity}/{color_code}_{cardname}.jpg'
#      65 response = requests.get(image_url)
# ---> 66 time.sleep(0.2)
#      67 if response.status_code == 200:
#      68     with open (save_path, 'wb') as file:
#
# KeyboardInterrupt:

# %%
r = requests.get(f"https://api.scryfall.com/cards/search?q=airship+engine+room").json()
r
# Out:
# {'object': 'list',
#  'total_cards': 1,
#  'has_more': False,
#  'data': [{'object': 'card',
#    'id': '0b98ba34-f251-4bd0-9d75-1d4445be5cfd',
#    'oracle_id': '01ed9139-293d-4477-a145-3c6fe59266c7',
#    'multiverse_ids': [],
#    'tcgplayer_id': 661971,
#    'cardmarket_id': 857750,
#    'name': 'Airship Engine Room',
#    'lang': 'en',
#    'released_at': '2025-11-21',
#    'uri': 'https://api.scryfall.com/cards/0b98ba34-f251-4bd0-9d75-1d4445be5cfd',
#    'scryfall_uri': 'https://scryfall.com/card/tla/265/airship-engine-room?utm_source=api',
#    'layout': 'normal',
#    'highres_image': True,
#    'image_status': 'highres_scan',
#    'image_uris': {'small': 'https://cards.scryfall.io/small/front/0/b/0b98ba34-f251-4bd0-9d75-1d4445be5cfd.jpg?1762187901',
#     'normal': 'https://cards.scryfall.io/normal/front/0/b/0b98ba34-f251-4bd0-9d75-1d4445be5cfd.jpg?1762187901',
#     'large': 'https://cards.scryfall.io/large/front/0/b/0b98ba34-f251-4bd0-9d75-1d4445be5cfd.jpg?1762187901',
#     'png': 'https://cards.scryfall.io/png/front/0/b/0b98ba34-f251-4bd0-9d75-1d4445be5cfd.png?1762187901',
#     'art_crop': 'https://cards.scryfall.io/art_crop/front/0/b/0b98ba34-f251-4bd0-9d75-1d4445be5cfd.jpg?1762187901',
#     'border_crop': 'https://cards.scryfall.io/border_crop/front/0/b/0b98ba34-f251-4bd0-9d75-1d4445be5cfd.jpg?1762187901'},
#    'mana_cost': '',
#    'cmc': 0.0,
#    'type_line': 'Land',
#    'oracle_text': 'This land enters tapped.\n{T}: Add {U} or {R}.\n{4}, {T}, Sacrifice this land: Draw a card.',
#    'colors': [],
#    'color_identity': ['R', 'U'],
#    'keywords': [],
#    'produced_mana': ['R', 'U'],
#    'legalities': {'standard': 'not_legal',
#     'future': 'not_legal',
#     'historic': 'not_legal',
#     'timeless': 'not_legal',
#     'gladiator': 'not_legal',
#     'pioneer': 'not_legal',
#     'modern': 'not_legal',
#     'legacy': 'not_legal',
#     'pauper': 'not_legal',
#     'vintage': 'not_legal',
#     'penny': 'not_legal',
#     'commander': 'not_legal',
#     'oathbreaker': 'not_legal',
#     'standardbrawl': 'not_legal',
#     'brawl': 'not_legal',
#     'alchemy': 'not_legal',
#     'paupercommander': 'not_legal',
#     'duel': 'not_legal',
#     'oldschool': 'not_legal',
#     'premodern': 'not_legal',
#     'predh': 'not_legal'},
#    'games': ['paper', 'arena', 'mtgo'],
#    'reserved': False,
#    'game_changer': False,
#    'foil': True,
#    'nonfoil': True,
#    'finishes': ['nonfoil', 'foil'],
#    'oversized': False,
#    'promo': False,
#    'reprint': False,
#    'variation': False,
#    'set_id': '118f7e64-5caa-4cb7-99a8-184f4d3a7422',
#    'set': 'tla',
#    'set_name': 'Avatar: The Last Airbender',
#    'set_type': 'expansion',
#    'set_uri': 'https://api.scryfall.com/sets/118f7e64-5caa-4cb7-99a8-184f4d3a7422',
#    'set_search_uri': 'https://api.scryfall.com/cards/search?order=set&q=e%3Atla&unique=prints',
#    'scryfall_set_uri': 'https://scryfall.com/sets/tla?utm_source=api',
#    'rulings_uri': 'https://api.scryfall.com/cards/0b98ba34-f251-4bd0-9d75-1d4445be5cfd/rulings',
#    'prints_search_uri': 'https://api.scryfall.com/cards/search?order=released&q=oracleid%3A01ed9139-293d-4477-a145-3c6fe59266c7&unique=prints',
#    'collector_number': '265',
#    'digital': False,
#    'rarity': 'common',
#    'flavor_text': "The Fire Nation's expansion fueled progress, and their progress fueled expansion.",
#    'card_back_id': '0aeebaf5-8c7d-4636-9e82-8c27447861f7',
#    'artist': 'Andreas Rocha',
#    'artist_ids': ['d084e74b-f63a-4107-b72c-ed6250ecc93b'],
#    'illustration_id': '72b4a65f-9ddd-4691-a04d-ff37b125fda8',
#    'border_color': 'black',
#    'frame': '2015',
#    'full_art': False,
#    'textless': False,
#    'booster': False,
#    'story_spotlight': False,
#    'promo_types': ['universesbeyond'],
#    'edhrec_rank': 27902,
#    'prices': {'usd': None,
#     'usd_foil': '1.00',
#     'usd_etched': None,
#     'eur': None,
#     'eur_foil': None,
#     'tix': None},
#    'related_uris': {'tcgplayer_infinite_articles': 'https://partner.tcgplayer.com/c/4931599/1830156/21018?subId1=api&trafcat=tcgplayer.com%2Fsearch%2Farticles&u=https%3A%2F%2Fwww.tcgplayer.com%2Fsearch%2Farticles%3FproductLineName%3Dmagic%26q%3DAirship%2BEngine%2BRoom',
#     'tcgplayer_infinite_decks': 'https://partner.tcgplayer.com/c/4931599/1830156/21018?subId1=api&trafcat=tcgplayer.com%2Fsearch%2Fdecks&u=https%3A%2F%2Fwww.tcgplayer.com%2Fsearch%2Fdecks%3FproductLineName%3Dmagic%26q%3DAirship%2BEngine%2BRoom',
#     'edhrec': 'https://edhrec.com/route/?cc=Airship+Engine+Room'},
#    'purchase_uris': {'tcgplayer': 'https://partner.tcgplayer.com/c/4931599/1830156/21018?subId1=api&u=https%3A%2F%2Fwww.tcgplayer.com%2Fproduct%2F661971%3Fpage%3D1',
#     'cardmarket': 'https://www.cardmarket.com/en/Magic/Products?idProduct=857750&referrer=scryfall&utm_campaign=card_prices&utm_medium=text&utm_source=scryfall',
#     'cardhoarder': 'https://www.cardhoarder.com/cards?affiliate_id=scryfall&data%5Bsearch%5D=Airship+Engine+Room&ref=card-profile&utm_campaign=affiliate&utm_medium=card&utm_source=scryfall'}}]}
