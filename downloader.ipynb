# %%
import requests
import time
import os

# %%
#make directories for set if it doesnt exist 
os.makedirs('images/tla', exist_ok=True)
for rarity in ['common', 'uncommon', 'rare', 'mythic']:
    #make directories for rarity if it doesnt exist
    os.makedirs(f'images/tla/{rarity}', exist_ok=True)
    #get all cards in the draft set, change the query for other sets
    r = requests.get(f"https://api.scryfall.com/cards/search?q=e:tla+cn>=1+cn<=286+r:{rarity}").json()
    #respect api rules
    time.sleep(0.1)
    print('got', r.get('total_cards'), 'cards of rarity', rarity)
    cards = r.get('data')
    #iterate through all cards for current rarity
    for card in cards:
        cardname = card.get('name')
        #handle mdfc cards and // in names
        if '/' in cardname:
            cardname = cardname.replace('/', '_')

        #create color identity mapping to group images by color in file explorer, remove if not interested in sorty by color and only by name
        color = card.get('color_identity')
        color_mapping = {
            'W' : '1',
            'U' : '2',
            'B' : '3',
            'R' : '4',
            'G' : '5'
        }
        if color is None or len(color) == 0:
            color_code = '0'
        elif len(color) > 1:
            color_code = '6'
        else:
            color_code = color_mapping.get(color[0])

        #special handling of MDFC cards to get both faces 
        if card.get('card_faces') is not None:
            # for color mapping of mdfc cards, use color of first face to keep the cards together in the file explorer
            first = card.get('card_faces')[0]
            color = first.get('color')
            if color is None or len(color) == 0:
                color_code = '0'
            elif len(color) > 1:
                color_code = '6'
            else:
                color_code = color_mapping.get(color[0])
            for idx, cardface in enumerate(card.get('card_faces')):
                image_url = cardface.get('image_uris').get('normal')
                save_path = f'images/tla/{rarity}/{color_code}_{cardname}_{idx}.jpg'
                response = requests.get(image_url)
                time.sleep(0.2)
                if response.status_code == 200:    
                    with open (save_path, 'wb') as file:
                        file.write(response.content)
                    print(f'downloaded image for {cardname}')
                else:
                    print(f"Failed to download image for {cardname}")
        else:
            #get image url and download image
            image_url = card.get('image_uris').get('normal')
            save_path = f'images/tla/{rarity}/{color_code}_{cardname}.jpg'
            response = requests.get(image_url)
            time.sleep(0.2)
            if response.status_code == 200:    
                with open (save_path, 'wb') as file:
                    file.write(response.content)
                print(f'downloaded image for {cardname}')
            else:
                print(f"Failed to download image for {cardname}")
# Out:
# got 96 cards of rarity common
# downloaded image for Aang's Journey
# downloaded image for Abandon Attachments
# downloaded image for Airbending Lesson
# downloaded image for Airship Engine Room
# downloaded image for Avatar Enthusiasts
# downloaded image for Azula Always Lies
# downloaded image for Badgermole
# downloaded image for Barrels of Blasting Jelly
# downloaded image for Beetle-Headed Merchants
# downloaded image for Bender's Waterskin
# downloaded image for Boar-q-pine
# downloaded image for Boiling Rock Prison
# downloaded image for Bumi Bash
# downloaded image for Callous Inspector
# downloaded image for Canyon Crawler
# downloaded image for Cat-Owl
# downloaded image for Compassionate Healer
# downloaded image for Corrupt Court Official
# downloaded image for Cunning Maneuver
# downloaded image for Curious Farm Animals
# downloaded image for Cycle of Renewal
# downloaded image for Dai Li Indoctrination
# downloaded image for Deadly Precision
# downloaded image for Deserter's Disciple
# downloaded image for Earthbending Lesson
# downloaded image for Earth Kingdom Soldier
# downloaded image for Earth Rumble Wrestlers
# downloaded image for Earth Village Ruffians
# downloaded image for Firebending Lesson
# downloaded image for Fire Nation Cadets
# downloaded image for Fire Nation Raider
# downloaded image for First-Time Flyer
# downloaded image for Flexible Waterbender
# downloaded image for Foggy Bottom Swamp
# downloaded image for Foggy Swamp Hunters
# downloaded image for Foggy Swamp Vinebender
# downloaded image for Forecasting Fortune Teller
# downloaded image for Forest
# downloaded image for Geyser Leaper
# downloaded image for Giant Koi
# downloaded image for Glider Kids
# downloaded image for Hog-Monkey
# downloaded image for How to Start a Riot
# downloaded image for Iguana Parrot
# downloaded image for Island
# downloaded image for It'll Quench Ya!
# downloaded image for Jeong Jeong's Deserters
# downloaded image for Kyoshi Battle Fan
# downloaded image for Kyoshi Village
# downloaded image for Kyoshi Warriors
# downloaded image for Lightning Strike
# downloaded image for Lost Days
# downloaded image for Meditation Pools
# downloaded image for Merchant of Many Hats
# downloaded image for Messenger Hawk
# downloaded image for Misty Palms Oasis
# downloaded image for Mongoose Lizard
# downloaded image for Mountain
# downloaded image for North Pole Gates
# downloaded image for Octopus Form
# downloaded image for Omashu City
# downloaded image for Origin of Metalbending
# downloaded image for Ostrich-Horse
# downloaded image for Otter-Penguin
# downloaded image for Path to Redemption
# downloaded image for Pillar Launch
# downloaded image for Pirate Peddlers
# downloaded image for Plains
# downloaded image for Platypus-Bear
# downloaded image for Pretending Poxbearers
# downloaded image for Rabaroo Troop
# downloaded image for Raucous Audience
# downloaded image for Razor Rings
# downloaded image for Rebellious Captives
# downloaded image for Rocky Rebuke
# downloaded image for Rough Rhino Cavalry
# downloaded image for Rowdy Snowballers
# downloaded image for Rumble Arena
# downloaded image for Saber-Tooth Moose-Lion
# downloaded image for Sandbenders' Storm
# downloaded image for Serpent's Pass
# downloaded image for Sold Out
# downloaded image for Sun-Blessed Peak
# downloaded image for Swamp
# downloaded image for Swampsnare Trap
# downloaded image for Treetop Freedom Fighters
# downloaded image for Turtle-Duck
# downloaded image for Vindictive Warden
# downloaded image for Walltop Sentries
# downloaded image for Wandering Musicians
# downloaded image for Waterbending Lesson
# downloaded image for Water Tribe Captain
# downloaded image for Watery Grasp
# downloaded image for Yip Yip!
# downloaded image for Yuyan Archers
# downloaded image for Zuko's Exile
# got 110 cards of rarity uncommon
# downloaded image for Aang, the Last Airbender
# downloaded image for Accumulate Wisdom
# downloaded image for Airbender's Reversal
# downloaded image for Air Nomad Legacy
# downloaded image for Allies at Last
# downloaded image for Appa, Loyal Sky Bison
# downloaded image for Azula, On the Hunt
# downloaded image for Benevolent River Spirit
# downloaded image for Bitter Work
# downloaded image for Boomerang Basics
# downloaded image for Bumi, King of Three Trials
# downloaded image for Buzzard-Wasp Colony
# downloaded image for Cat-Gator
# downloaded image for Combustion Man
# downloaded image for Combustion Technique
# downloaded image for Crashing Wave
# downloaded image for Crescent Island Temple
# downloaded image for Cruel Administrator
# downloaded image for Dai Li Agents
# downloaded image for Destined Confrontation
# downloaded image for Dragonfly Swarm
# downloaded image for Earth Kingdom General
# downloaded image for Earth Kingdom Jailer
# downloaded image for Earth Kingdom Protectors
# downloaded image for Earth Rumble
# downloaded image for Ember Island Production
# downloaded image for Energybending
# downloaded image for Enter the Avatar State
# downloaded image for Epic Downfall
# downloaded image for Fancy Footwork
# downloaded image for Fatal Fissure
# downloaded image for Fire Nation Attacks
# downloaded image for Fire Nation Engineer
# downloaded image for Fire Nation Warship
# downloaded image for Fire Navy Trebuchet
# downloaded image for Fire Sages
# downloaded image for Flopsie, Bumi's Buddy
# downloaded image for Foggy Swamp Spirit Keeper
# downloaded image for Gather the White Lotus
# downloaded image for Glider Staff
# downloaded image for Gran-Gran
# downloaded image for Guru Pathik
# downloaded image for Hama, the Bloodbender
# downloaded image for Haru, Hidden Talent
# downloaded image for Heartless Act
# downloaded image for Hei Bai, Spirit of Balance
# downloaded image for Hermitic Herbalist
# downloaded image for Honest Work
# downloaded image for Invasion Reinforcements
# downloaded image for Invasion Submersible
# downloaded image for Invasion Tactics
# downloaded image for Iroh's Demonstration
# downloaded image for Jeong Jeong, the Deserter
# downloaded image for Jet, Freedom Fighter
# downloaded image for Jet's Brainwashing
# downloaded image for Joo Dee, One of Many
# downloaded image for June, Bounty Hunter
# downloaded image for Katara, Bending Prodigy
# downloaded image for Knowledge Seeker
# downloaded image for Kyoshi Island Plaza
# downloaded image for Leaves from the Vine
# downloaded image for Lo and Li, Twin Tutors
# downloaded image for Long Feng, Grand Secretariat
# downloaded image for Mai, Jaded Edge
# downloaded image for Master Pakku
# downloaded image for Master Piandao
# downloaded image for Meteor Sword
# downloaded image for Momo, Playful Pet
# downloaded image for Northern Air Temple
# downloaded image for North Pole Patrol
# downloaded image for Ozai's Cruelty
# downloaded image for Price of Freedom
# downloaded image for Professor Zei, Anthropologist
# downloaded image for Rockalanche
# downloaded image for Ruinous Waterbending
# downloaded image for Seismic Sense
# downloaded image for Serpent of the Pass
# downloaded image for Shared Roots
# downloaded image for Sokka, Lateral Strategist
# downloaded image for Sokka's Haiku
# downloaded image for Solstice Revelations
# downloaded image for Southern Air Temple
# downloaded image for Sparring Dummy
# downloaded image for Suki, Kyoshi Warrior
# downloaded image for Sun Warriors
# downloaded image for Team Avatar
# downloaded image for Teo, Spirited Glider
# downloaded image for The Boulder, Ready to Rumble
# downloaded image for The Cave of Two Lovers
# downloaded image for The Spirit Oasis
# downloaded image for Tiger-Dillo
# downloaded image for Tolls of War
# downloaded image for Toph, the Blind Bandit
# downloaded image for True Ancestry
# downloaded image for Trusty Boomerang
# downloaded image for Tundra Tank
# downloaded image for Twin Blades
# downloaded image for Ty Lee, Artful Acrobat
# downloaded image for Uncle Iroh
# downloaded image for Unlucky Cabbage Merchant
# downloaded image for Vengeful Villagers
# downloaded image for War Balloon
# downloaded image for Waterbending Scroll
# downloaded image for Water Tribe Rallier
# downloaded image for White Lotus Hideout
# downloaded image for White Lotus Reinforcements
# downloaded image for Wolfbat
# downloaded image for Zhao, Ruthless Admiral
# downloaded image for Zuko, Exiled Prince
# downloaded image for Zuko's Conviction
# got 60 cards of rarity rare
# downloaded image for Aang, at the Crossroads __ Aang, Destined Savior
# downloaded image for Aang, at the Crossroads __ Aang, Destined Savior
# downloaded image for Aang's Iceberg
# downloaded image for Aang, Swift Savior __ Aang and La, Ocean's Fury
# downloaded image for Aang, Swift Savior __ Aang and La, Ocean's Fury
# downloaded image for Abandoned Air Temple
# downloaded image for Agna Qel'a
# downloaded image for Airbender Ascension
# downloaded image for Avatar Destiny
# downloaded image for Avatar's Wrath
# downloaded image for Azula, Cunning Usurper
# downloaded image for Ba Sing Se
# downloaded image for Beifong's Bounty Hunters
# downloaded image for Boiling Rock Rioter
# downloaded image for Day of Black Sun
# downloaded image for Diligent Zookeeper
# downloaded image for Earthbender Ascension
# downloaded image for Earthen Ally
# downloaded image for Earth King's Lieutenant
# downloaded image for Elemental Teachings
# downloaded image for Firebender Ascension
# downloaded image for Firebending Student
# downloaded image for Fire Lord Azula
# downloaded image for Fire Lord Zuko
# downloaded image for Fire Nation Palace
# downloaded image for Foggy Swamp Visions
# downloaded image for Great Divide Guide
# downloaded image for Hakoda, Selfless Commander
# downloaded image for Iroh, Grand Lotus
# downloaded image for Iroh, Tea Master
# downloaded image for Jasmine Dragon Tea Shop
# downloaded image for Katara, the Fearless
# downloaded image for Katara, Water Tribe's Hope
# downloaded image for Mai, Scornful Striker
# downloaded image for Momo, Friendly Flier
# downloaded image for Obsessive Pursuit
# downloaded image for Ran and Shaw
# downloaded image for Raven Eagle
# downloaded image for Realm of Koh
# downloaded image for Redirect Lightning
# downloaded image for Sandbender Scavengers
# downloaded image for Secret Tunnel
# downloaded image for Sokka, Bold Boomeranger
# downloaded image for Sokka, Tenacious Tactician
# downloaded image for South Pole Voyager
# downloaded image for Spirit Water Revival
# downloaded image for Suki, Courageous Rescuer
# downloaded image for The Earth King
# downloaded image for The Fire Nation Drill
# downloaded image for The Last Agni Kai
# downloaded image for The Lion-Turtle
# downloaded image for The Mechanist, Aerial Artisan
# downloaded image for The Unagi of Kyoshi Island
# downloaded image for Tiger-Seal
# downloaded image for Toph, Hardheaded Teacher
# downloaded image for Toph, the First Metalbender
# downloaded image for Ty Lee, Chi Blocker
# downloaded image for Wartime Protestors
# downloaded image for Waterbender Ascension
# downloaded image for Yue, the Moon Spirit
# downloaded image for Zhao, the Moon Slayer
# downloaded image for Zuko, Conflicted
# got 20 cards of rarity mythic
# downloaded image for Appa, Steadfast Guardian
# downloaded image for Avatar Aang __ Aang, Master of Elements
# downloaded image for Avatar Aang __ Aang, Master of Elements
# downloaded image for Badgermole Cub
# downloaded image for Bumi, Unleashed
# downloaded image for Fated Firepower
# downloaded image for Koh, the Face Stealer
# downloaded image for Ozai, the Phoenix King
# downloaded image for Phoenix Fleet Airship
# downloaded image for Planetarium of Wan Shi Tong
# downloaded image for Secret of Bloodbending
# downloaded image for Sozin's Comet
# downloaded image for The Legend of Kuruk __ Avatar Kuruk
# downloaded image for The Legend of Kuruk __ Avatar Kuruk
# downloaded image for The Legend of Kyoshi __ Avatar Kyoshi
# downloaded image for The Legend of Kyoshi __ Avatar Kyoshi
# downloaded image for The Legend of Roku __ Avatar Roku
# downloaded image for The Legend of Roku __ Avatar Roku
# downloaded image for The Legend of Yangchen __ Avatar Yangchen
# downloaded image for The Legend of Yangchen __ Avatar Yangchen
# downloaded image for The Rise of Sozin __ Fire Lord Sozin
# downloaded image for The Rise of Sozin __ Fire Lord Sozin
# downloaded image for The Walls of Ba Sing Se
# downloaded image for United Front
# downloaded image for Wan Shi Tong, Librarian
# downloaded image for White Lotus Tile
